# %%
# 필요한 라이브러리 임포트
import pandas as pd

# CSV 파일 읽기
file_path = '000660_SK하이닉스_20150101_20240828.csv'  # 원본 CSV 파일 경로
data = pd.read_csv(file_path)

# 필요한 컬럼 리스트
columns_to_extract = [
    'date', 'open', 'high', 'low', 'close', 'volume', 
    'per', 'pbr', 'roe', 'open_lastclose_ratio', 
    'high_close_ratio', 'low_close_ratio', 'diffratio', 
    'volume_lastvolume_ratio', 'close_ma5_ratio', 
    'volume_ma5_ratio', 'close_ma10_ratio', 
    'volume_ma10_ratio', 'close_ma20_ratio', 
    'volume_ma20_ratio', 'close_ma60_ratio', 
    'volume_ma60_ratio', 'close_ma120_ratio', 
    'volume_ma120_ratio', 'ind', 'ind_diff', 
    'ind_ma5', 'ind_ma10', 'ind_ma20', 
    'ind_ma60', 'ind_ma120', 'inst', 
    'inst_diff', 'inst_ma5', 'inst_ma10', 
    'inst_ma20', 'inst_ma60', 'inst_ma120', 
    'foreign', 'foreign_diff', 
    'foreign_ma5', 'foreign_ma10', 
    'foreign_ma20', 'foreign_ma60', 
    'foreign_ma120'
]

# 필요한 컬럼만 추출
extracted_data = data[columns_to_extract]

# 새로운 CSV 파일로 저장
output_file_path = '000660_SK하이닉스.csv'  # 저장할 CSV 파일 경로
extracted_data.to_csv(output_file_path, index=False)

extracted_data
# Out:
#           date    open    high     low   close   volume   per   pbr    roe  \
# 0     20150102   47950   48400   47650   47750  1155944  6.44  0.89  15.63
# 1     20150105   48050   48400   47500   47650  1409146  6.44  0.89  15.63
# 2     20150106   47000   47600   46900   47500  1661196  6.44  0.89  15.63
# 3     20150107   46700   47600   46700   47400  1821266  6.44  0.89  15.63
# 4     20150108   48250   50000   47900   49950  5006675  6.44  0.89  15.63
# ...        ...     ...     ...     ...     ...      ...   ...   ...    ...
# 2369  20240821  193000  195400  191100  192600  4508983  5.03  1.04  24.26
# 2370  20240822  192000  194400  189000  191100  3166217  5.03  1.04  24.26
# 2371  20240823  186000  189300  185400  185500  4371332  5.03  1.04  24.26
# 2372  20240826  187800  188500  179600  179600  4913204  5.03  1.04  24.26
# 2373  20240827  176800  180200  173400  175000  5741455  5.03  1.04  24.26
#
# ...

# %%
# 필요한 라이브러리 임포트
import pandas as pd

# CSV 파일 읽기
file_path = '005380_현대차_20150101_20240828.csv'  # 원본 CSV 파일 경로
data = pd.read_csv(file_path)

# 필요한 컬럼 리스트
columns_to_extract = [
    'date', 'open', 'high', 'low', 'close', 'volume', 
    'per', 'pbr', 'roe', 'open_lastclose_ratio', 
    'high_close_ratio', 'low_close_ratio', 'diffratio', 
    'volume_lastvolume_ratio', 'close_ma5_ratio', 
    'volume_ma5_ratio', 'close_ma10_ratio', 
    'volume_ma10_ratio', 'close_ma20_ratio', 
    'volume_ma20_ratio', 'close_ma60_ratio', 
    'volume_ma60_ratio', 'close_ma120_ratio', 
    'volume_ma120_ratio', 'ind', 'ind_diff', 
    'ind_ma5', 'ind_ma10', 'ind_ma20', 
    'ind_ma60', 'ind_ma120', 'inst', 
    'inst_diff', 'inst_ma5', 'inst_ma10', 
    'inst_ma20', 'inst_ma60', 'inst_ma120', 
    'foreign', 'foreign_diff', 
    'foreign_ma5', 'foreign_ma10', 
    'foreign_ma20', 'foreign_ma60', 
    'foreign_ma120'
]

# 필요한 컬럼만 추출
extracted_data = data[columns_to_extract]

# 새로운 CSV 파일로 저장
output_file_path = '005380_현대자동차.csv'  # 저장할 CSV 파일 경로
extracted_data.to_csv(output_file_path, index=False)

extracted_data
# Out:
#           date    open    high     low   close  volume   per   pbr    roe  \
# 0     20150102  169000  170500  167000  169000  458014  7.93  0.64   8.93
# 1     20150105  171000  171000  166000  168000  454073  7.93  0.64   8.93
# 2     20150106  166500  167000  164000  164500  635059  7.93  0.64   8.93
# 3     20150107  163000  171500  163000  170000  511006  7.93  0.64   8.93
# 4     20150108  172500  178000  171000  178000  902742  7.93  0.64   8.93
# ...        ...     ...     ...     ...     ...     ...   ...   ...    ...
# 2369  20240821  257500  257500  251000  252500  359513  4.76  0.53  12.01
# 2370  20240822  253500  254000  245500  248000  497250  4.76  0.53  12.01
# 2371  20240823  245500  254000  245000  252500  449189  4.76  0.53  12.01
# 2372  20240826  255500  258000  247500  249500  469538  4.76  0.53  12.01
# 2373  20240827  248500  251000  244500  247500  546990  4.76  0.53  12.01
#
#       open_lastclose_ratio  ...  inst_ma20  inst_ma60  inst_ma120   foreign  \
# ...

# %%
# 필요한 라이브러리 임포트
import pandas as pd

# CSV 파일 읽기
file_path = '035720_카카오_20150101_20240828.csv'  # 원본 CSV 파일 경로
data = pd.read_csv(file_path)

# 필요한 컬럼 리스트
columns_to_extract = [
    'date', 'open', 'high', 'low', 'close', 'volume', 
    'per', 'pbr', 'roe', 'open_lastclose_ratio', 
    'high_close_ratio', 'low_close_ratio', 'diffratio', 
    'volume_lastvolume_ratio', 'close_ma5_ratio', 
    'volume_ma5_ratio', 'close_ma10_ratio', 
    'volume_ma10_ratio', 'close_ma20_ratio', 
    'volume_ma20_ratio', 'close_ma60_ratio', 
    'volume_ma60_ratio', 'close_ma120_ratio', 
    'volume_ma120_ratio', 'ind', 'ind_diff', 
    'ind_ma5', 'ind_ma10', 'ind_ma20', 
    'ind_ma60', 'ind_ma120', 'inst', 
    'inst_diff', 'inst_ma5', 'inst_ma10', 
    'inst_ma20', 'inst_ma60', 'inst_ma120', 
    'foreign', 'foreign_diff', 
    'foreign_ma5', 'foreign_ma10', 
    'foreign_ma20', 'foreign_ma60', 
    'foreign_ma120'
]

# 필요한 컬럼만 추출
extracted_data = data[columns_to_extract]

# 새로운 CSV 파일로 저장
output_file_path = '035720_카카오.csv'  # 저장할 CSV 파일 경로
extracted_data.to_csv(output_file_path, index=False)

extracted_data
# Out:
#           date   open   high    low  close   volume    per   pbr    roe  \
# 0     20150102  24880  27740  24860  27440  5814505  50.89  6.83  14.81
# 1     20150105  28100  29160  27920  28900  6872685  50.89  6.83  14.81
# 2     20150106  28860  29860  28500  29060  5229540  50.89  6.83  14.81
# 3     20150107  28800  29860  28560  29640  4295315  50.89  6.83  14.81
# 4     20150108  29980  30300  29300  29460  3656030  50.89  6.83  14.81
# ...        ...    ...    ...    ...    ...      ...    ...   ...    ...
# 2369  20240821  36500  36800  36400  36600   669506  26.58  1.49   5.83
# 2370  20240822  36900  37700  36750  37550  1653724  26.58  1.49   5.83
# 2371  20240823  37450  37800  37100  37450   872362  26.58  1.49   5.83
# 2372  20240826  37550  38900  37150  38700  1753855  26.58  1.49   5.83
# 2373  20240827  38650  38900  38000  38000  1142253  26.58  1.49   5.83
#
#       open_lastclose_ratio  ...  inst_ma20  inst_ma60  inst_ma120   foreign  \
# ...
